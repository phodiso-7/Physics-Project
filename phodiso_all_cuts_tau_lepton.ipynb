# %%
from phodiso_tools import *


path = '/home/ml-hep/phodiso_events/ilc500sig_ta_nu/Events/run_01/tag_1_delphes_events.root'

df = open_root_collab(path)

# df

# %%
df_had_sig , df_dijet , df_4 , df_5 , df_cut_sig = all_tau_cuts(df,5,5,0.5)
# Out:
# +--------------------+----------+--------------+-------------+
# | Cut                |   Events | Efficiency   | Rejection   |
# +====================+==========+==============+=============+
# | input events       |    40000 | -            | -           |
# +--------------------+----------+--------------+-------------+
# | Hadronic Tau decay |    22649 | 0.5662       | 0.4338      |
# +--------------------+----------+--------------+-------------+
# +--------------+----------+--------------+-------------+
# | Cut          |   Events | Efficiency   | Rejection   |
# +==============+==========+==============+=============+
# | input events |    22649 | -            | -           |
# +--------------+----------+--------------+-------------+
# | Tau di_jet   |     4621 | 0.2040       | 0.7960      |
# +--------------+----------+--------------+-------------+
# +--------------+----------+--------------+-------------+
# | Cut          |   Events | Efficiency   | Rejection   |
# ...

# %% [markdown]
# ## e+ e- >> w+ w-

# %%
# df_w = open_root_collab('/home/ml-hep/phodiso_events/14sep_w_back/Events/run_01/tag_1_delphes_events.root')


####w + w- background

df_w_ta = open_root_collab('/home/ml-hep/phodiso_events/14sep_w_back_ta/Events/run_01/tag_1_delphes_events.root')

df_had_w , df_dijet , df_4 , df_5 , df_cut_w = all_tau_cuts(df_w_ta,5,5,0.5)
# Out:
# +--------------------+----------+--------------+-------------+
# | Cut                |   Events | Efficiency   | Rejection   |
# +====================+==========+==============+=============+
# | input events       |    40000 | -            | -           |
# +--------------------+----------+--------------+-------------+
# | Hadronic Tau decay |    18159 | 0.4540       | 0.5460      |
# +--------------------+----------+--------------+-------------+
# +--------------+----------+--------------+-------------+
# | Cut          |   Events | Efficiency   | Rejection   |
# +==============+==========+==============+=============+
# | input events |    18159 | -            | -           |
# +--------------+----------+--------------+-------------+
# | Tau di_jet   |     3050 | 0.1680       | 0.8320      |
# +--------------+----------+--------------+-------------+
# +--------------+----------+--------------+-------------+
# | Cut          |   Events | Efficiency   | Rejection   |
# ...

# %%
t_b = 0.01263

t_s = 0.0002155

c_s = t_s # 40000/10

c_b = t_b   #40000/10

n = 22649

n2 = 18159

open_plot_tau(masses = [150] , signal_dfs = [df_had_sig] , background_dfs = [df_had_w]  )

# %%
open_plot_tau(masses = [150] , signal_dfs = [df_cut_sig] , background_dfs = [df_cut_w] , offset=[0.15,80,0]  )

# %% [markdown]
# ### e+ e- >> z z

# %%
df_zz_ta = open_root_collab('/home/ml-hep/phodiso_events/14sep_zz_back_ta/Events/run_01/tag_1_delphes_events.root')

df_had_zz , df_dijet , df_4 , df_5 , df_cut_zz = all_tau_cuts(df_zz_ta,5,5,0.5)

open_plot_tau(masses = [150] , signal_dfs = [df_had_sig] , background_dfs = [df_had_zz]  )
# Out:
# +--------------------+----------+--------------+-------------+
# | Cut                |   Events | Efficiency   | Rejection   |
# +====================+==========+==============+=============+
# | input events       |    40000 | -            | -           |
# +--------------------+----------+--------------+-------------+
# | Hadronic Tau decay |    27952 | 0.6988       | 0.3012      |
# +--------------------+----------+--------------+-------------+
# +--------------+----------+--------------+-------------+
# | Cut          |   Events | Efficiency   | Rejection   |
# +==============+==========+==============+=============+
# | input events |    27952 | -            | -           |
# +--------------+----------+--------------+-------------+
# | Tau di_jet   |    11084 | 0.3965       | 0.6035      |
# +--------------+----------+--------------+-------------+
# +--------------+----------+--------------+-------------+
# | Cut          |   Events | Efficiency   | Rejection   |
# ...

# %%
open_plot_tau(masses = [150] , signal_dfs = [df_cut_sig] , background_dfs = [df_cut_zz] , offset = [0.06,0,10]  )

# %% [markdown]
# ## e+ e- > w+ ta- vt~ , e+ e- > w- ta+ vt

# %%
df_w_ta_nu = open_root_collab('/home/ml-hep/phodiso_events/14sep_w_ta_nu/Events/run_01/tag_1_delphes_events.root')

df_had_w_ta_nu , df_dijet , df_4 , df_5 , df_cut_w_ta_nu = all_tau_cuts(df_w_ta_nu,5,5,0.5)

open_plot_tau(masses = [150] , signal_dfs = [df_had_sig] , background_dfs = [df_had_w_ta_nu]  )

print("After cuts")

open_plot_tau(masses = [150] , signal_dfs = [df_cut_sig] , background_dfs = [df_cut_w_ta_nu] , offset = [0,0,0]  )
# Out:
# +--------------------+----------+--------------+-------------+
# | Cut                |   Events | Efficiency   | Rejection   |
# +====================+==========+==============+=============+
# | input events       |    40000 | -            | -           |
# +--------------------+----------+--------------+-------------+
# | Hadronic Tau decay |    13735 | 0.3434       | 0.6566      |
# +--------------------+----------+--------------+-------------+
# +--------------+----------+--------------+-------------+
# | Cut          |   Events | Efficiency   | Rejection   |
# +==============+==========+==============+=============+
# | input events |    13735 | -            | -           |
# +--------------+----------+--------------+-------------+
# | Tau di_jet   |      508 | 0.0370       | 0.9630      |
# +--------------+----------+--------------+-------------+
# +--------------+----------+--------------+-------------+
# | Cut          |   Events | Efficiency   | Rejection   |
# ...

# %% [markdown]
# ## e+ e- > z ta+ ta-

# %%
df_z_ta_ta = open_root_collab('/home/ml-hep/phodiso_events/14sep_z_ta_ta/Events/run_01/tag_1_delphes_events.root')

df_had_z_ta_ta , df_dijet , df_4 , df_5 , df_cut_z_ta_ta = all_tau_cuts(df_z_ta_ta,5,5,0.5)
# Out:
# +--------------------+----------+--------------+-------------+
# | Cut                |   Events | Efficiency   | Rejection   |
# +====================+==========+==============+=============+
# | input events       |    40000 | -            | -           |
# +--------------------+----------+--------------+-------------+
# | Hadronic Tau decay |    20744 | 0.5186       | 0.4814      |
# +--------------------+----------+--------------+-------------+
# +--------------+----------+--------------+-------------+
# | Cut          |   Events | Efficiency   | Rejection   |
# +==============+==========+==============+=============+
# | input events |    20744 | -            | -           |
# +--------------+----------+--------------+-------------+
# | Tau di_jet   |     3806 | 0.1835       | 0.8165      |
# +--------------+----------+--------------+-------------+
# +--------------+----------+--------------+-------------+
# | Cut          |   Events | Efficiency   | Rejection   |
# ...

# %% [markdown]
# ## e+ e- >> ta+ ta-

# %%
df_ta_ta = open_root_collab('/home/ml-hep/phodiso_events/14sep_ta_ta/Events/run_01/tag_1_delphes_events.root')

df_had_ta_ta , df_dijet , df_4 , df_5 , df_cut_ta_ta = all_tau_cuts(df_ta_ta,5,5,0.5)

open_plot_tau(masses = [150] , signal_dfs = [df_had_sig] , background_dfs = [df_had_ta_ta]  )

print("After cuts######################################################")

open_plot_tau(masses = [150] , signal_dfs = [df_cut_sig] , background_dfs = [df_cut_ta_ta] , offset = [0,0,0]  )
# Out:
# +--------------------+----------+--------------+-------------+
# | Cut                |   Events | Efficiency   | Rejection   |
# +====================+==========+==============+=============+
# | input events       |    40000 | -            | -           |
# +--------------------+----------+--------------+-------------+
# | Hadronic Tau decay |    24567 | 0.6142       | 0.3858      |
# +--------------------+----------+--------------+-------------+
# +--------------+----------+--------------+-------------+
# | Cut          |   Events | Efficiency   | Rejection   |
# +==============+==========+==============+=============+
# | input events |    24567 | -            | -           |
# +--------------+----------+--------------+-------------+
# | Tau di_jet   |     5681 | 0.2312       | 0.7688      |
# +--------------+----------+--------------+-------------+
# +--------------+----------+--------------+-------------+
# | Cut          |   Events | Efficiency   | Rejection   |
# ...
